# %% [markdown]
# <a href="https://colab.research.google.com/github/matthewsillence/educational_discourse/blob/master/word_count.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
### Word count of source files

with open('/content/ed_01.txt', 'r', encoding='utf-8') as f_in:
    words = f_in.read()
    count = words.split()
    print(count)
    print(len(count))
# Out:
# ['\ufeffUK', 'Quality', 'Code', 'for', 'Higher', 'Education', 'Advice', 'and', 'Guidance', 'Research', 'Degrees', '1', 'Contents', 'Regulatory', 'contexts', 'for', 'the', 'Quality', 'Code', '1', 'Terminology', '1', 'Expectations', 'and', 'Practices', '2', 'Guiding', 'principles', '4', 'Practical', 'advice', '5', 'Writing', 'group', '13', 'Regulatory', 'contexts', 'for', 'the', 'Quality', 'Code', 'The', 'Expectatios', 'and', 'Core', 'practices', 'of', 'the', 'UK', 'Quality', 'Code', 'for', 'Higher', 'Education', '(Quality', 'Code)', 'are', 'mandatory', 'for', 'higher', 'education', 'providers', 'in', 'all', 'parts', 'of', 'the', 'UK.', 'Common', 'practices', 'are', 'mandatory', 'in', 'Scotland,', 'Wales', 'and', 'Northern', 'Ireland', 'and', 'while', 'providers', 'in', 'England', 'may', 'choose', 'to', 'work', 'towards', 'them,', 'they', 'are', 'not', 'required', 'to', 'do', 'so', 'as', 'these', 'are', 'not', 'regulatory', 'requirements', 'and', 'will', 'not', 'be', 'assessed', 'as', 
# ...
